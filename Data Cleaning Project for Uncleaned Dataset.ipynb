# %% [markdown]
# # Project Title:
#    # Data Cleaning Project for Uncleaned Dataset

# %% [markdown]
# # Objective:
# - The primary objective of this project is to clean and
#   preprocess an unclean dataset containing various inconsistencies
#   and mixed data fields to ensure high-quality data for further analysis.

# %% [markdown]
# # Dataset Description
#
# - Dataset: The dataset consists of employee records with fields like Name, Date of Birth, Email ID, Job Type, and Department.
# - The data is unclean with mixed fields and special characters.

# %%
# Import Necessary Libraries
import pandas as pd

import re

# %%
data = pd.read_csv(r'unclean_data.csv')

# %%
unclean_data = data.copy()

# %%
unclean_data
# Out:
#              Name                    Date_of_Birth_EmailID    Job_Type  \
# 0        John@Doe           1990-01-15john.doe@example.com  Full$-Time
# 1      Jane$Smith         jane.smith@company.com1992-03-22   Part!Time
# 2  Michael&Jordan  1985-07-30michael.jordan@basketball.org   Con%tract
# 3     Emily!Brown      emily.brown@example.co.uk1988-11-10  Ful^l-Time
# 4   Robert#Taylor      1995-05-17robert.taylor@example.net  Par^t-Time
# 5   Sophia$Walker      1993-09-12sophia.walker@fashion.com  Full-T^ime
# 6     Chris!Evans         chris.evans@movies.com1982-06-13  Fre$elance
# 7     Emma@Watson       1990-04-15emma.watson@hogwarts.edu     Inter^n
# 8    Daniel#Craig           daniel.craig@007.com1968-03-02   Con!tract
# 9  Olivia%Johnson     olivia.johnson@example.org1991-08-25   Ful$-Time
#
#                  Department
# 0              Enginee@ring
# 1                Market#ing
# 2                    Sa$les
# 3          Human Reso@urces
# 4  Inform@ation Technolo%gy
# 5                   De%sign
# 6               Produc!tion
# 7                Educa@tion
# 8                 Secur#ity
# 9               Opera#tions

# %% [markdown]
# # Data Cleaning Steps
# - 1) Remove Special Characters from names, job types, and departments.
#
# - 2) Separate Dates of Birth from email IDs.
#
# - 3) Split Names into First and Last Names.
# - 4) Make Proper Sequence of Columns

# %%
# Step - 1
#Create function
def to_clean_data(data):
    data['Name'] = re.sub(r'[@$&!#%^]',' ',data['Name'])
    data['Job_Type'] = re.sub(r'[@$&!#%^]','',data['Job_Type'])
    data['Department'] = re.sub(r'[@$&!#%^]','',data['Department'])
    return data

# %%
unclean_data = unclean_data.apply(to_clean_data,axis = 1)

# %%
unclean_data
# Out:
#              Name                    Date_of_Birth_EmailID   Job_Type  \
# 0        John Doe           1990-01-15john.doe@example.com  Full-Time
# 1      Jane Smith         jane.smith@company.com1992-03-22   PartTime
# 2  Michael Jordan  1985-07-30michael.jordan@basketball.org   Contract
# 3     Emily Brown      emily.brown@example.co.uk1988-11-10  Full-Time
# 4   Robert Taylor      1995-05-17robert.taylor@example.net  Part-Time
# 5   Sophia Walker      1993-09-12sophia.walker@fashion.com  Full-Time
# 6     Chris Evans         chris.evans@movies.com1982-06-13  Freelance
# 7     Emma Watson       1990-04-15emma.watson@hogwarts.edu     Intern
# 8    Daniel Craig           daniel.craig@007.com1968-03-02   Contract
# 9  Olivia Johnson     olivia.johnson@example.org1991-08-25   Ful-Time
#
#                Department
# 0             Engineering
# 1               Marketing
# 2                   Sales
# 3         Human Resources
# 4  Information Technology
# 5                  Design
# 6              Production
# 7               Education
# 8                Security
# 9              Operations

# %%
# Step - 2
# Create function to seprate Email-ID and DOB
def to_split_mail_dob(data):
    dob = re.search(r'\d{4}-\d{2}-\d{2}',data['Date_of_Birth_EmailID'])
    data['Date_of_Birth'] = dob.group(0)
    data['Email_ID'] = data['Date_of_Birth_EmailID'].replace(data['Date_of_Birth'],'')
    return data

# %%
unclean_data = unclean_data.apply(to_split_mail_dob, axis = 1)

# %%
unclean_data
# Out:
#              Name                    Date_of_Birth_EmailID   Job_Type  \
# 0        John Doe           1990-01-15john.doe@example.com  Full-Time
# 1      Jane Smith         jane.smith@company.com1992-03-22   PartTime
# 2  Michael Jordan  1985-07-30michael.jordan@basketball.org   Contract
# 3     Emily Brown      emily.brown@example.co.uk1988-11-10  Full-Time
# 4   Robert Taylor      1995-05-17robert.taylor@example.net  Part-Time
# 5   Sophia Walker      1993-09-12sophia.walker@fashion.com  Full-Time
# 6     Chris Evans         chris.evans@movies.com1982-06-13  Freelance
# 7     Emma Watson       1990-04-15emma.watson@hogwarts.edu     Intern
# 8    Daniel Craig           daniel.craig@007.com1968-03-02   Contract
# 9  Olivia Johnson     olivia.johnson@example.org1991-08-25   Ful-Time
#
#                Department Date_of_Birth                       Email_ID
# 0             Engineering    1990-01-15           john.doe@example.com
# 1               Marketing    1992-03-22         jane.smith@company.com
# 2                   Sales    1985-07-30  michael.jordan@basketball.org
# 3         Human Resources    1988-11-10      emily.brown@example.co.uk
# 4  Information Technology    1995-05-17      robert.taylor@example.net
# 5                  Design    1993-09-12      sophia.walker@fashion.com
# 6              Production    1982-06-13         chris.evans@movies.com
# 7               Education    1990-04-15       emma.watson@hogwarts.edu
# 8                Security    1968-03-02           daniel.craig@007.com
# 9              Operations    1991-08-25     olivia.johnson@example.org

# %%
# Step - 4
# Create Function To Split name and surname
def to_split_name(data):
    data['First_name'] = data['Name'].split(' ')[0]
    data['Last_name'] = data['Name'].split(' ')[1]
    return data

# %%
unclean_data = unclean_data.apply(to_split_name, axis = 1)

# %%
unclean_data
# Out:
#              Name                    Date_of_Birth_EmailID   Job_Type  \
# 0        John Doe           1990-01-15john.doe@example.com  Full-Time
# 1      Jane Smith         jane.smith@company.com1992-03-22   PartTime
# 2  Michael Jordan  1985-07-30michael.jordan@basketball.org   Contract
# 3     Emily Brown      emily.brown@example.co.uk1988-11-10  Full-Time
# 4   Robert Taylor      1995-05-17robert.taylor@example.net  Part-Time
# 5   Sophia Walker      1993-09-12sophia.walker@fashion.com  Full-Time
# 6     Chris Evans         chris.evans@movies.com1982-06-13  Freelance
# 7     Emma Watson       1990-04-15emma.watson@hogwarts.edu     Intern
# 8    Daniel Craig           daniel.craig@007.com1968-03-02   Contract
# 9  Olivia Johnson     olivia.johnson@example.org1991-08-25   Ful-Time
#
#                Department Date_of_Birth                       Email_ID  \
# 0             Engineering    1990-01-15           john.doe@example.com
# 1               Marketing    1992-03-22         jane.smith@company.com
# 2                   Sales    1985-07-30  michael.jordan@basketball.org
# 3         Human Resources    1988-11-10      emily.brown@example.co.uk
# 4  Information Technology    1995-05-17      robert.taylor@example.net
# 5                  Design    1993-09-12      sophia.walker@fashion.com
# 6              Production    1982-06-13         chris.evans@movies.com
# 7               Education    1990-04-15       emma.watson@hogwarts.edu
# 8                Security    1968-03-02           daniel.craig@007.com
# 9              Operations    1991-08-25     olivia.johnson@example.org
#
#   First_name Last_name
# 0       John       Doe
# 1       Jane     Smith
# 2    Michael    Jordan
# 3      Emily     Brown
# 4     Robert    Taylor
# 5     Sophia    Walker
# 6      Chris     Evans
# 7       Emma    Watson
# 8     Daniel     Craig
# 9     Olivia   Johnson

# %%
unclean_data = unclean_data.drop(columns=['Name','Date_of_Birth_EmailID'])

# %%
# Step - 4
unclean_data = unclean_data[['First_name','Last_name','Date_of_Birth','Email_ID',"Department","Job_Type"]]

# %%
unclean_data
# Out:
#     Job_Type              Department Date_of_Birth  \
# 0  Full-Time             Engineering    1990-01-15
# 1   PartTime               Marketing    1992-03-22
# 2   Contract                   Sales    1985-07-30
# 3  Full-Time         Human Resources    1988-11-10
# 4  Part-Time  Information Technology    1995-05-17
# 5  Full-Time                  Design    1993-09-12
# 6  Freelance              Production    1982-06-13
# 7     Intern               Education    1990-04-15
# 8   Contract                Security    1968-03-02
# 9   Ful-Time              Operations    1991-08-25
#
#                         Email_ID First_name Last_name
# 0           john.doe@example.com       John       Doe
# 1         jane.smith@company.com       Jane     Smith
# 2  michael.jordan@basketball.org    Michael    Jordan
# 3      emily.brown@example.co.uk      Emily     Brown
# 4      robert.taylor@example.net     Robert    Taylor
# 5      sophia.walker@fashion.com     Sophia    Walker
# 6         chris.evans@movies.com      Chris     Evans
# 7       emma.watson@hogwarts.edu       Emma    Watson
# 8           daniel.craig@007.com     Daniel     Craig
# 9     olivia.johnson@example.org     Olivia   Johnson

# %%
# Export clean data-set as csv for EDA

# %%
unclean_data.to_csv('clean_data.csv',index = True)

# %% [markdown]
# # Results
# - Summarizing the outcome of the data-cleaning process.
#
# - Cleaned Dataset: The dataset has been cleaned, with special characters removed,
#  fields properly separated, and names split into first and last names.
# The resulting dataset is now ready for analysis.

# %% [markdown]
# # Importance of Data Cleaning
# Why data cleaning is crucial in any data-related project.
#
# 1) Data Quality: Clean data ensures accuracy, consistency, and reliability of analysis results.
#
# 2) Improved Model Performance: Machine learning models perform better with clean data, leading to more accurate predictions.
#
# 3) Efficiency: Clean data reduces the time spent on troubleshooting data-related issues during analysis or model training.
#
# 4) Insights and Decision-Making: High-quality data leads to more reliable insights, which are essential for informed decision-making.
